# %%
print('신도림' in '서울특별시 구로구 신도림동()')
# Out:
# True

# %%
import csv
f = open('2024.csv',encoding='utf-8')
data = csv.reader(f)
next(data)

for row in data:
    if '운정3동' in row[0]:
        print(row)
# Out:
# ['경기도 파주시 운정3동(4148057000)', '68,374', '68,374', '300', '343', '422', '481', '514', '577', '669', '763', '923', '942', '941', '890', '990', '914', '961', '919', '991', '958', '839', '781', '792', '778', '686', '781', '885', '779', '797', '730', '718', '767', '714', '774', '788', '777', '758', '768', '962', '957', '1,073', '1,087', '1,107', '1,350', '1,452', '1,515', '1,557', '1,469', '1,219', '1,343', '1,287', '1,297', '1,355', '1,338', '1,361', '1,402', '1,239', '1,146', '1,090', '878', '813', '853', '789', '721', '759', '736', '721', '658', '626', '594', '545', '587', '456', '390', '408', '259', '288', '310', '309', '332', '242', '219', '204', '240', '234', '184', '212', '158', '114', '111', '101', '88', '49', '40', '40', '26', '19', '12', '9', '10', '4', '3', '7']
