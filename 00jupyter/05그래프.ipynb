# %%
import matplotlib.pyplot as plt

year = [2014,2015,2016,2017,2018,2019,2020,2021,2022]
gdp = [3079.9,3250.1,3398.8,3574,3678.2,3721.8,3744,4003.6,4165.5]

plt.plot(year,gdp)
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2014,2015,2016,2017,2018,2019,2020,2021,2022]
gdp = [3079.9,3250.1,3398.8,3574,3678.2,3721.8,3744,4003.6,4165.5]

plt.figure(figsize=(5,4))
# plt.plot(year,gdp,color='g',marker='+',linestyle='--')
plt.plot(year,gdp,'--og')
plt.title('GDP per capita')
plt.xlabel('years')
plt.ylabel('ten thousand won')
plt.show()

# %%
import matplotlib.pyplot as plt

year = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
seoul = [12.1,12,12.2,12.5,13.4,13.6,13.6,13,12.9,13.5,13.2,13.7,13.2]
jeju = [15.6,15.6,15.7,16.5,16.2,16.7,17,16.8,16.6,16.8,16.7,17.5,17]

plt.figure(figsize=(6,4))
plt.plot(year,seoul,label='seoul')
plt.plot(year,jeju,label='jeju')
plt.ylim(10,20)
plt.xlim(2009,2023)


plt.text(year[-1],seoul[-1],'Seoul')
plt.text(year[-1],jeju[-1],'Jeju')
plt.title('years temp mean')
plt.xlabel('year')
# plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

season = ['spring', 'summer', 'autumn', 'winter']
precipitation = [330.5, 612.8, 256.4, 13.3]

plt.figure(figsize=(5,3))
plt.bar(season,precipitation)
plt.title('precipitation')
plt.ylabel('mm')
plt.ylim(0,800)
plt.show()

# %%
import matplotlib.pyplot as plt
preci = {'spring':330.5, 'summer':612.8, 'autumn':256.4, 'winter':13.3}

# plt.bar(항목이름,항목 값)
# print(preci.keys())
# print(preci.values())

plt.figure(figsize=(5,4))
plt.bar(preci.keys(),preci.values(),color='#f0f')
plt.show()

# %%
import matplotlib.pyplot as plt
year = [2000, 2005, 2010, 2015, 2020]
single_person = [15.5, 20.0, 23.9, 27.2, 31.7]
baby_born = [640089, 438707, 470171, 438420, 272337]

plt.figure(figsize=(5,3))
plt.scatter(single_person,baby_born,c='r',marker='^')
plt.xlabel('single-person house')
plt.ylabel('the number of babies')
plt.show()

# %%
import matplotlib.pyplot as plt
height = [156.9,159.9,153.5,151.2,154.6,168.3,165,154.7,146,152.4]
weight = [48.7,58.5,48.4,39,58.9,80.8,59.3,49.4,35.3,51.8]
gender = ['f','f','f','f','f','m','m','m','m','m','s']
# color = [x for x in range(10)  ]

color1 = ['r' if a=='f' else 'b' if a == 's' else 'y'  for a in gender]

print(color)

plt.figure(figsize=(5,3))
plt.scatter(height,weight,c=color)
plt.xlabel('height')
plt.ylabel('weight')
plt.show()
# Out:
# ['r', 'r', 'r', 'r', 'r', 'b', 'b', 'b', 'b', 'b']

# %%
gender = ['f','f','f','f','f','m','m','m','m','m','s']
color1 = ['r' if a=='f' else 'b' if a == 'm' else 'y'  for a in gender]
print(color1)
# Out:
# ['r', 'r', 'r', 'r', 'r', 'b', 'b', 'b', 'b', 'b', 'y']
