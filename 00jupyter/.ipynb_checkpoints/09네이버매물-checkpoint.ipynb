# %%
import requests
import json
import pandas as pd
import time

cookies = {
    'NNB': 'T3A66WDXG6IGO',
    'NFS': '2',
    'ASID': '70debbf6000001948ca7d30500000052',
    'nstore_session': 'NNDM684efqDiMefXQbYBj5E1',
    '_fbp': 'fb.1.1741683147985.984744443137571443',
    'nstore_pagesession': 'i+uYQlqrhKjx8lsLd9w-401600',
    'ba.uuid': '1a24377f-ebce-4426-9a40-c10cd2638ae7',
    'tooltipDisplayed': 'true',
    '_gcl_au': '1.1.1839640797.1747039740',
    '_ga_J5CZVNJNQP': 'GS2.1.s1747039739$o1$g0$t1747039740$j0$l0$h0',
    '_fwb': '222FxwLQFL83Vm29nownPZw.1747814452634',
    'landHomeFlashUseYn': 'Y',
    '_fwb': '222FxwLQFL83Vm29nownPZw.1747814452634',
    'NAC': 'pjBmBoQSYhUr',
    '_ga': 'GA1.2.883948427.1747039740',
    'nhn.realestate.article.rlet_type_cd': 'A01',
    'nhn.realestate.article.trade_type_cd': '""',
    'SRT30': '1749605342',
    'nid_inf': '1968924701',
    'NID_AUT': '/r/fwg+dkfkvcMvMoc9sxCBfdnkZo7NAYMmu2gqRo6P7kLvCcToUhZ+D7Rqfokbz',
    'NACT': '1',
    'NID_SES': '...',
    'SRT5': '1749609383',
    'realestate.beta.lastclick.cortar': '1156000000',
    'REALESTATE': 'Wed%20Jun%2011%202025%2011%3A43%3A01%20GMT%2B0900%20(Korean%20Standard%20Time)',
    'BUC': 'iK_M5YY0JgDRkUXYkhgoCx-QYZmY3bTOBjUBrXCWlNg=',
}

headers = {
    'accept': '*/*',
    'accept-language': 'ko,ko-KR;q=0.9,en;q=0.8',
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE3NDk2MDk3ODEsImV4cCI6MTc0OTYyMDU4MX0.2XSvc9BgMBpDTyNt7Gm_HBf7uOkleHzUMYfEUvIwxQY',
    'priority': 'u=1, i',
    'referer': 'https://new.land.naver.com/complexes/653?ms=37.728361,126.734569,16&a=APT:PRE:ABYG:JGC&e=RETAIL&articleNo=2531258558',
    'sec-ch-ua': '"Google Chrome";v="137", "Chromium";v="137", "Not/A)Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36',
    # 'cookie': 'NNB=T3A66WDXG6IGO; NFS=2; ASID=70debbf6000001948ca7d30500000052; nstore_session=NNDM684efqDiMefXQbYBj5E1; _fbp=fb.1.1741683147985.984744443137571443; nstore_pagesession=i+uYQlqrhKjx8lsLd9w-401600; ba.uuid=1a24377f-ebce-4426-9a40-c10cd2638ae7; tooltipDisplayed=true; _gcl_au=1.1.1839640797.1747039740; _ga_J5CZVNJNQP=GS2.1.s1747039739$o1$g0$t1747039740$j0$l0$h0; _fwb=222FxwLQFL83Vm29nownPZw.1747814452634; landHomeFlashUseYn=Y; _fwb=222FxwLQFL83Vm29nownPZw.1747814452634; NAC=pjBmBoQSYhUr; _ga=GA1.2.883948427.1747039740; nhn.realestate.article.rlet_type_cd=A01; nhn.realestate.article.trade_type_cd=""; SRT30=1749605342; nid_inf=1968924701; NID_AUT=/r/fwg+dkfkvcMvMoc9sxCBfdnkZo7NAYMmu2gqRo6P7kLvCcToUhZ+D7Rqfokbz; NACT=1; NID_SES=...; SRT5=1749609383; realestate.beta.lastclick.cortar=1156000000; REALESTATE=Wed%20Jun%2011%202025%2011%3A43%3A01%20GMT%2B0900%20(Korean%20Standard%20Time); BUC=iK_M5YY0JgDRkUXYkhgoCx-QYZmY3bTOBjUBrXCWlNg=',
}

# response = requests.get(
#     'https://new.land.naver.com/api/articles/complex/3354?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=1&buildingNos=&areaNos=&type=list&order=rank',
#     cookies=cookies,
#     headers=headers,
# )


# url = 'https://new.land.naver.com/api/articles/complex/137'

# params = {
#     'realEstateType': 'APT:PRE:ABYG:JGC',
#     'tradeType': '',
#     'tag': ':::::::',
#     'rentPriceMin': 0,
#     'rentPriceMax': 900000000,
#     'priceMin': 0,
#     'priceMax': 900000000,
#     'areaMin': 0,
#     'areaMax': 900000000,
#     'oldBuildYears': '',
#     'recentlyBuildYears': '',
#     'minHouseHoldCount': '',
#     'maxHouseHoldCount': '',
#     'showArticle': 'false',
#     'sameAddressGroup': 'false',
#     'minMaintenanceCost': '',
#     'maxMaintenanceCost': '',
#     'priceType': 'RETAIL',
#     'directions': '',
#     'page': 1,
#     'buildingNos': '',
#     'areaNos': '',
#     'type': 'list',
#     'order': 'rank'
# }

# response = requests.get(url, headers=headers, cookies=cookies, params=params)



# data = json.loads(response.text)
# dataView= data['articleList']

dataList = []

# isMoreData = True

def get_data(page):
    url = f'https://new.land.naver.com/api/articles/complex/3354?realEstateType=APT%3APRE%3AABYG%3AJGC&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page={page}&buildingNos=&areaNos=&type=list&order=rank'
    response = requests.get(url, headers=headers, cookies=cookies)
    return json.loads(response.text)



is_more = True
page = 1


while is_more:
    print(f'{page} 페이지 수집중')
    data = get_data(page)
    dataView= data['articleList']
    if not dataView:
        print("비어 있네요")
        break
        
    for i in dataView:
        dataList.append({
            'articleNo':i['articleNo'],
            "articleName":i["articleName"],
            "tradeTypeName":i["tradeTypeName"],
            "tagList":i["tagList"],
            "dealOrWarrantPrc":i["dealOrWarrantPrc"],
        })

    # is_more = data['isMoreData'] if 'isMoreData' in data else False

    is_more = data.get('isMoreData',False)

    page += 1
    time.sleep(1)
    

df = pd.DataFrame(dataList)
df.to_csv('naver_.csv',index=False,encoding='utf-8-sig')



# print(response.text)
# Out:
# 1 페이지 수집중
# 2 페이지 수집중
# 3 페이지 수집중
# 4 페이지 수집중
# 5 페이지 수집중
# 6 페이지 수집중
# 7 페이지 수집중
