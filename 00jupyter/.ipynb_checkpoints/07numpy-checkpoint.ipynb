# %%
import numpy as np
data = [1,2,3,4,5]

print(type(data))
arr = np.array(data)
print(type(arr))
print(arr)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# [1 2 3 4 5]

# %%
import numpy as np

arr = np.array([1,2,3,4,5])
print(arr[0])
print(arr[1:4])
print(arr[:3])
print(arr[2:])
# Out:
# 1
# ['2' '3' '4']
# ['1' '2' '3']
# ['3' '4' '5']
