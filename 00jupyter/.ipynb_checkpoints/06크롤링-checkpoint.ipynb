# %%
from bs4 import BeautifulSoup


html = '''
<html>
  <body>
    <div id="main">
      <h1 class="title">파이썬 웹 스크래핑</h1>
      <h1>test</h1>
      <p class="desc">BeautifulSoup를 이용한 데이터 추출 예제</p>
      <a href="https://example.com" class="link">더 알아보기</a>
      <ul class="items">
        <li data-id="101">첫 번째</li>
        <li data-id="102">두 번째</li>
        <li data-id="103">세 번째</li>
      </ul>
    </div>
  </body>
</html>
'''


soup = BeautifulSoup(html, "html.parser")

# 1.soup.find("tag")
h1_tag = soup.find('li')
print(h1_tag)


# 2. soup.find("tag",class_="desc")
p_tag = soup.find("p",class_="desc")
print(p_tag.text)

# 3. soup.find_all("tag")
# li_tags = soup.find_all("li")
# print(li_tags)
# for li in li_tags:
#     print("-",li.text)

# 4. soup.select("css 선택자")
css_li = soup.select("ul.items  li")
for li in css_li:
    print("o", li.text)
# Out:
# <li data-id="101">첫 번째</li>
# BeautifulSoup를 이용한 데이터 추출 예제
# o 첫 번째
# o 두 번째
# o 세 번째

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'}
data= requests.get("https://www.melon.com/chart/",headers=headers)
soup = BeautifulSoup(data.text,'html.parser')

# print(soup)

# title_one = soup.select_one("#tb_list table .lst50 .ellipsis.rank01 a")
# print(title_one.text)

top_50 = soup.select('#lst50 > td > div')

for row in top_50:
    rank = row.select_one('span.rank')
    if rank is not None:
        print(rank.text,end=". ")
  
    title = row.select_one('.ellipsis.rank01 > span > a')
    if title is not None:
        print(title.text,end = " - ")

    singer = row.select_one('.ellipsis.rank02 > span > a')
    if singer is not None:
        print(singer.text)
# Out:
# 1. 너에게 닿기를 - 10CM
# 2. Drowning - WOODZ
# 3. Never Ending Story - 아이유
# 4. 모르시나요(PROD.로코베리) - 조째즈
# 5. like JENNIE - 제니 (JENNIE)
# 6. TOO BAD (feat. Anderson .Paak) - G-DRAGON
# 7. THUNDER - 세븐틴 (SEVENTEEN)
# 8. 어제보다 슬픈 오늘 - 우디 (Woody)
# 9. 나는 반딧불 - 황가람
# 10. Whiplash - aespa
# 11. HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# 12. 오늘만 I LOVE YOU - BOYNEXTDOOR
# 13. REBEL HEART - IVE (아이브)
# 14. Flower - 오반(OVAN)
# 15. HAPPY - DAY6 (데이식스)
# 16. 네모의 꿈 - 아이유
# 17. APT. - 로제 (ROSÉ)
# 18. 청춘만화 - 이무진
# 19. HOT - LE SSERAFIM (르세라핌)
# 20. 한 페이지가 될 수 있게 - DAY6 (데이식스)
# 21. 시작의 아이 - 마크툽 (MAKTUB)
# 22. MY LOVE(2025) - 이예은
# 23. 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# 24. Welcome to the Show - DAY6 (데이식스)
# 25. 소나기 - 이클립스 (ECLIPSE)
# 26. Die With A Smile - Lady Gaga
# 27. 천상연 - 이창섭
# 28. HANDS UP - MEOVV (미야오)
# 29. 그날이 오면 - 투모로우바이투게더
# 30. toxic till the end - 로제 (ROSÉ)
# 31. 예뻤어 - DAY6 (데이식스)
# 32. Supernova - aespa
# 33. ATTITUDE - IVE (아이브)
# 34. I DO ME - KiiiKiii (키키)
# 35. 미치게 그리워서 - 황가람
# 36. 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU (악뮤)
# 37. Fly Up - RIIZE
# 38. 사랑은 늘 도망가 - 임영웅
# 39. HBD - 세븐틴 (SEVENTEEN)
# 40. 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션 (Nerd Connection)
# 41. PO￦ER - G-DRAGON
# 42. Love wins all - 아이유
# 43. 내 이름 맑음 - QWER
# 44. DRIP - BABYMONSTER
# 45. 청혼하지 않을 이유를 못 찾았어 - 이무진
# 46. Skyfall (THE 8 Solo) - 세븐틴 (SEVENTEEN)
# 47. 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# 48. 슬픈 초대장 - 순순희(지환)
# 49. 고민중독 - QWER
# 50. 주저하는 연인들을 위해 - 잔나비

# %%
from datetime import datetime,timedelta

today = datetime.today()
one_month_ago = today - timedelta(days=30)

dates = [
    datetime(2025,5,1),
    datetime(2025,5,20),
    datetime(2025,6,4),
]

type(dates[0])
print(one_month_ago )

for date_parsed in dates:
    if one_month_ago <= date_parsed <= today: # one_month_ago <= date_parsed  and date_parsed <= today:
        print(f'{date_parsed.date()} 는 최근 1개월 안입니다. ')
    else:
        print(f'{date_parsed.date()} 는 최근 1개월 밖 ')
# Out:
# 2025-05-05 14:49:44.912301
# 2025-05-01 는 최근 1개월 밖
# 2025-05-20 는 최근 1개월 안입니다.
# 2025-06-04 는 최근 1개월 안입니다.

# %%
import requests
from datetime import datetime,timedelta
from bs4 import BeautifulSoup
import time
import pandas as pd

url = 'https://finance.naver.com/item/sise_day.naver?code=005930'
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'
}

data = []
today = datetime.today()
one_month_ago = today - timedelta(days=30)
for page in range(1,5):
    response = requests.get(f'{url}&page={page}',headers=headers)
    
    html = response.text
    soup = BeautifulSoup(html,"html.parser")
    table = soup.find('table',class_="type2")
    rows = table.find_all('tr')
    # print(len(rows))
    for row in rows:
        cols = row.find_all('td')
        if len(cols) < 7:
            continue

        data.append({
            'date':cols[0].text.strip(),
            'close':cols[1].text.strip().replace(",",""),
            'open':cols[3].text.strip().replace(",",""),
            'high':cols[4].text.strip().replace(",",""),
            'low':cols[5].text.strip().replace(",",""),
            'volume':cols[6].text.strip().replace(",",""),
        
        })
    time.sleep(2)

df=pd.DataFrame(data)

print(df)
# Out:
#           date  close   open   high    low    volume
# 0   2025.06.04  57800  57200  57900  56800  19390304
# 1   2025.06.02  56800  56300  57300  56200  12870515
# 2   2025.05.30  56200  56200  57200  55800  26219683
# 3   2025.05.29  56100  56200  56400  55600  12936810
# 4   2025.05.28  55900  54300  56100  54200  17516283
# 5   2025.05.27  53900  54200  54500  53800  13439520
# 6   2025.05.26  54700  53900  55000  53700  10901337
# 7   2025.05.23  54200  55000  55200  54100  11247115
# 8   2025.05.22  54700  55300  55500  54500  15254278
# 9   2025.05.21  55700  56200  56600  55700   7794181
# 10  2025.05.20  55900  56200  56700  55700   9080577
# 11  2025.05.19  55800  56400  56400  55500   9802105
# 12  2025.05.16  56800  57400  57500  56700  10385352
# 13  2025.05.15  57300  57400  58600  57100  13139736
# 14  2025.05.14  57400  57500  57900  57000  12468089
# 15  2025.05.13  56900  57700  58200  56800  16842801
# 16  2025.05.12  57600  55200  57600  55000  15414702
# 17  2025.05.09  54800  54700  55000  54400   7814322
# 18  2025.05.08  54600  55100  55500  54500  16320532
# 19  2025.05.07  54600  54500  55000  54300  17136991
# 20  2025.05.02  54300  55000  55500  54200  22454204
# 21  2025.04.30  55500  55900  56000  55300  13014189
# 22  2025.04.29  55800  55700  56500  55600  10295518
# 23  2025.04.28  55800  55800  55900  55500   9341518
# 24  2025.04.25  55700  56400  56400  55600  12183303
# 25  2025.04.24  55700  55600  55800  55200  10580377
# 26  2025.04.23  55700  56000  56100  55500  11148692
# 27  2025.04.22  55000  54900  55500  54700   9532469
# 28  2025.04.21  55400  55200  56000  55100   5941847
# 29  2025.04.18  55300  55300  55600  54900   5848342
# 30  2025.04.17  55100  54700  55300  54500  10867069
# 31  2025.04.16  54700  56000  56200  54500  14437025
# 32  2025.04.15  56600  56300  57100  56200   8998640
# 33  2025.04.14  56200  56300  56700  55800  12852613
# 34  2025.04.11  55200  55600  55700  54800  13930480
# 35  2025.04.10  56400  56600  56700  55000  22948172
# 36  2025.04.09  53000  53300  54300  52900  20576960
# 37  2025.04.08  53500  55000  55300  53300  25532845
# 38  2025.04.07  53200  53300  54100  53100  31998883
# 39  2025.04.04  56100  56200  58200  55700  23527139
