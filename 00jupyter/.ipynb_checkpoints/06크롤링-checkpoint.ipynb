# %%
from bs4 import BeautifulSoup


html = '''
<html>
  <body>
    <div id="main">
      <h1 class="title">파이썬 웹 스크래핑</h1>
      <h1>test</h1>
      <p class="desc">BeautifulSoup를 이용한 데이터 추출 예제</p>
      <a href="https://example.com" class="link">더 알아보기</a>
      <ul class="items">
        <li data-id="101">첫 번째</li>
        <li data-id="102">두 번째</li>
        <li data-id="103">세 번째</li>
      </ul>
    </div>
  </body>
</html>
'''


soup = BeautifulSoup(html, "html.parser")

# 1.soup.find("tag")
h1_tag = soup.find('li')
print(h1_tag)


# 2. soup.find("tag",class_="desc")
p_tag = soup.find("p",class_="desc")
print(p_tag.text)

# 3. soup.find_all("tag")
# li_tags = soup.find_all("li")
# print(li_tags)
# for li in li_tags:
#     print("-",li.text)

# 4. soup.select("css 선택자")
css_li = soup.select("ul.items  li")
for li in css_li:
    print("o", li.text)
# Out:
# <li data-id="101">첫 번째</li>
# BeautifulSoup를 이용한 데이터 추출 예제
# o 첫 번째
# o 두 번째
# o 세 번째

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'}
data= requests.get("https://www.melon.com/chart/",headers=headers)
soup = BeautifulSoup(data.text,'html.parser')

# print(soup)

# title_one = soup.select_one("#tb_list table .lst50 .ellipsis.rank01 a")
# print(title_one.text)

top_50 = soup.select('#lst50 > td > div')

for row in top_50:
    rank = row.select_one('span.rank')
    if rank is not None:
        print(rank.text,end=". ")
  
    title = row.select_one('.ellipsis.rank01 > span > a')
    if title is not None:
        print(title.text,end = " - ")

    singer = row.select_one('.ellipsis.rank02 > span > a')
    if singer is not None:
        print(singer.text)
# Out:
# 1. 너에게 닿기를 - 10CM
# 2. Drowning - WOODZ
# 3. Never Ending Story - 아이유
# 4. 모르시나요(PROD.로코베리) - 조째즈
# 5. like JENNIE - 제니 (JENNIE)
# 6. 어제보다 슬픈 오늘 - 우디 (Woody)
# 7. THUNDER - 세븐틴 (SEVENTEEN)
# 8. TOO BAD (feat. Anderson .Paak) - G-DRAGON
# 9. Whiplash - aespa
# 10. HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# 11. 나는 반딧불 - 황가람
# 12. 시작의 아이 - 마크툽 (MAKTUB)
# 13. 오늘만 I LOVE YOU - BOYNEXTDOOR
# 14. HAPPY - DAY6 (데이식스)
# 15. REBEL HEART - IVE (아이브)
# 16. Flower - 오반(OVAN)
# 17. 청춘만화 - 이무진
# 18. APT. - 로제 (ROSÉ)
# 19. HOT - LE SSERAFIM (르세라핌)
# 20. 한 페이지가 될 수 있게 - DAY6 (데이식스)
# 21. 네모의 꿈 - 아이유
# 22. HANDS UP - MEOVV (미야오)
# 23. 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# 24. 천상연 - 이창섭
# 25. Welcome to the Show - DAY6 (데이식스)
# 26. 소나기 - 이클립스 (ECLIPSE)
# 27. MY LOVE(2025) - 이예은
# 28. Die With A Smile - Lady Gaga
# 29. Supernova - aespa
# 30. 예뻤어 - DAY6 (데이식스)
# 31. toxic till the end - 로제 (ROSÉ)
# 32. ATTITUDE - IVE (아이브)
# 33. 미치게 그리워서 - 황가람
# 34. 사랑은 늘 도망가 - 임영웅
# 35. I DO ME - KiiiKiii (키키)
# ...

# %%
from datetime import datetime,timedelta

today = datetime.today()
one_month_ago = today - timedelta(days=30)

dates = [
    datetime(2025,5,1),
    datetime(2025,5,20),
    datetime(2025,6,4),
]

type(dates[0])
print(one_month_ago )

for date_parsed in dates:
    if one_month_ago <= date_parsed <= today: # one_month_ago <= date_parsed  and date_parsed <= today:
        print(f'{date_parsed.date()} 는 최근 1개월 안입니다. ')
    else:
        print(f'{date_parsed.date()} 는 최근 1개월 밖 ')
# Out:
# 2025-05-05 14:49:44.912301
# 2025-05-01 는 최근 1개월 밖
# 2025-05-20 는 최근 1개월 안입니다.
# 2025-06-04 는 최근 1개월 안입니다.

# %%
import requests
from datetime import datetime,timedelta
from bs4 import BeautifulSoup
import time
import pandas as pd

url = 'https://finance.naver.com/item/sise_day.naver?code=005930'
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'
}

data = []
today = datetime.today()
one_month_ago = today - timedelta(days=30)
for page in range(1,5):
    response = requests.get(f'{url}&page={page}',headers=headers)
    
    html = response.text
    soup = BeautifulSoup(html,"html.parser")
    
    table = soup.find('table',class_="type2")
    rows = table.find_all('tr') #16
    # print(len(rows))
    for row in rows:
        cols = row.find_all('td')
        if len(cols) < 7: #true 이면 다음줄 실행 안하고 다음순번으로 
            continue

        date = cols[0].text.strip()
        date_parsed = datetime.strptime(date,'%Y.%m.%d')

        # print(date_parsed)

        if one_month_ago<= date_parsed <= today:
            data.append({
                'date':cols[0].text.strip(),
                'close':cols[1].text.strip().replace(",",""),
                'open':cols[3].text.strip().replace(",",""),
                'high':cols[4].text.strip().replace(",",""),
                'low':cols[5].text.strip().replace(",",""),
                'volume':cols[6].text.strip().replace(",",""),
            
            })
    time.sleep(2)
import pandas as pd
df=pd.DataFrame(data)
# print(type(df["date"]))
# df['date'] = pd.to_datetime(df["date"])
# df = df.sort_values(by="date",ascending=True)
print(df)
# Out:
#           date  close   open   high    low    volume
# 0   2025.06.05  59700  58100  59900  57900  10107616
# 1   2025.06.04  57800  57200  57900  56800  19649983
# 2   2025.06.02  56800  56300  57300  56200  12870515
# 3   2025.05.30  56200  56200  57200  55800  26219683
# 4   2025.05.29  56100  56200  56400  55600  12936810
# 5   2025.05.28  55900  54300  56100  54200  17516283
# 6   2025.05.27  53900  54200  54500  53800  13439520
# 7   2025.05.26  54700  53900  55000  53700  10901337
# 8   2025.05.23  54200  55000  55200  54100  11247115
# 9   2025.05.22  54700  55300  55500  54500  15254278
# 10  2025.05.21  55700  56200  56600  55700   7794181
# 11  2025.05.20  55900  56200  56700  55700   9080577
# 12  2025.05.19  55800  56400  56400  55500   9802105
# 13  2025.05.16  56800  57400  57500  56700  10385352
# 14  2025.05.15  57300  57400  58600  57100  13139736
# 15  2025.05.14  57400  57500  57900  57000  12468089
# 16  2025.05.13  56900  57700  58200  56800  16842801
# ...

# %%
import json
import pandas as pd
import time


import requests


cookies = {
    'PCID': '16247705314370002565497',
    'MARKETID': '16247705314370002565497',
    'x-coupang-accept-language': 'ko-KR',
    '_fbp': 'fb.1.1739079230308.913915237482103068',
    'gd1': 'Y',
    'srp_delivery_toggle': 'true',
    'delivery_toggle': 'false',
    'x-coupang-target-market': 'KR',
    'sid': '8d4ed3a2517f4473b8e97d53bc2f25284379b851',
    'searchKeyword': '%EC%95%84%EC%9D%B4%ED%8F%B0%2015|%EC%95%84%EC%9D%B4%ED%8F%B015',
    'searchKeywordType': '{%22%EC%95%84%EC%9D%B4%ED%8F%B0%2015%22:0}|{%22%EC%95%84%EC%9D%B4%ED%8F%B015%22:0}',
    'trac_src': '1042016',
    'trac_spec': '10304903',
    'trac_addtag': '900',
    'trac_ctag': 'HOME',
    'trac_lptag': '%EC%BF%A0%ED%8C%A1',
    'trac_itime': '20250610111420',
    '_abck': '59D6E61C9FC8339D97112BB1FC3EEAD5~0~...~-1~-1~1749024683',
    'cto_bundle': '',
    'baby-isWide': 'wide',
    'bm_lso': 'F3B84463E7DCB50D73F642EE4899B158D697A26F84EA0827ADE3CE923A08C050~...^1749527788750',
    'web-session-id': 'b3576bed-836c-442f-85d4-91433132b7cd',
    'overrideAbTestGroup': '%5B%5D',
    'bm_ss': 'ab8e18ef4e',
    'bm_mi': '5CB937F5670F2D9C86D6C7EB3E058EA1~~1',
    'bm_s': '...',
    'bm_so': '928DA6652CEAC539D4E86DACCE10BBF1A795EADB9533BB723DAA092E87653673~...',
    'bm_sv': 'D91ED0D67952D5669A60AE5179FB20B7~~1',
    'bm_sz': '353678DD00FCE68E045C2B03371D2D6C~...~3293750~3617590',
    'ak_bmsc': '4414E86A7C63BEAED4F2C61D1866664A~000000000000000000000000000000~...',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko,ko-KR;q=0.9,en;q=0.8',
    'baggage': 'sentry-environment=prod,sentry-release=prod-b3d20012b8a85b493001d628d5210e3c9f58e764,sentry-public_key=501af6039762e82f24831a3f1f892f3e,sentry-trace_id=591a07f4320fc7c8ed20450c322df1da,sentry-sampled=false,sentry-sample_rand=0.9362849224080863,sentry-sample_rate=0',
    'priority': 'u=1, i',
    'referer': 'https://www.coupang.com/vp/products/1703093047?vendorItemId=70887318328&sourceType=HOME_RELATED_ADS&searchId=feed-ac023547d7d048748fc0d984becd3dc7-related_ads&clickEventId=96704670-45ab-11f0-b47f-6abd7cd42abf',
    'sec-ch-ua': '"Google Chrome";v="137", "Chromium";v="137", "Not/A)Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'sentry-trace': '591a07f4320fc7c8ed20450c322df1da-9fb670a148816952-0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36',
    # 'cookie': 'PCID=16247705314370002565497; MARKETID=16247705314370002565497; x-coupang-accept-language=ko-KR; _fbp=fb.1.1739079230308.913915237482103068; gd1=Y; srp_delivery_toggle=true; delivery_toggle=false; x-coupang-target-market=KR; sid=8d4ed3a2517f4473b8e97d53bc2f25284379b851; searchKeyword=%EC%95%84%EC%9D%B4%ED%8F%B0%2015|%EC%95%84%EC%9D%B4%ED%8F%B015; searchKeywordType={%22%EC%95%84%EC%9D%B4%ED%8F%B0%2015%22:0}|{%22%EC%95%84%EC%9D%B4%ED%8F%B015%22:0}; trac_src=1042016; trac_spec=10304903; trac_addtag=900; trac_ctag=HOME; trac_lptag=%EC%BF%A0%ED%8C%A1; trac_itime=20250610111420; _abck=59D6E61C9FC8339D97112BB1FC3EEAD5~0~...~-1~-1~1749024683; cto_bundle=; baby-isWide=wide; bm_lso=F3B84463E7DCB50D73F642EE4899B158D697A26F84EA0827ADE3CE923A08C050~...^1749527788750; web-session-id=b3576bed-836c-442f-85d4-91433132b7cd; overrideAbTestGroup=%5B%5D; bm_ss=ab8e18ef4e; bm_mi=5CB937F5670F2D9C86D6C7EB3E058EA1~~1; bm_s=...; bm_so=928DA6652CEAC539D4E86DACCE10BBF1A795EADB9533BB723DAA092E87653673~...; bm_sv=D91ED0D67952D5669A60AE5179FB20B7~~1; bm_sz=353678DD00FCE68E045C2B03371D2D6C~...~3293750~3617590; ak_bmsc=4414E86A7C63BEAED4F2C61D1866664A~000000000000000000000000000000~...',
}

params = {
    'productId': '1703093047',
    'page': '1',
    'size': '10',
    'sortBy': 'ORDER_SCORE_ASC',
    'ratingSummary': 'true',
    'ratings': '',
    'market': '',
}


dataList = []


response = requests.get('https://www.coupang.com/next-api/review', params=params, cookies=cookies, headers=headers)
data = json.loads(response.text)

totalCount = data['rData']['paging']['totalCount']

totalPage = totalCount // 10

for i in range(1,10):
    params['page'] = i
    response = requests.get('https://www.coupang.com/next-api/review', params=params, cookies=cookies, headers=headers)
    data = json.loads(response.text)
    dataReview = data['rData']['paging']['contents']
    
    for i in dataReview:
        # dataList.append(
        #     i['reviewId']
        # )
        dataList.append(
            {
                'reviewId': i['reviewId'],
                'content':i['content'],
                'rating':i['rating'],
            }
        )

    
    time.sleep(2)
    

print(f'리뷰데이터 총 {len(dataList)} 개의 리뷰가 수집되었습니다.')

df = pd.DataFrame(dataList)
df.to_csv('doupang_review.csv',index=False,encoding='utf-8-sig')
